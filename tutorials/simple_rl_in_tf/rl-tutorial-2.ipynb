# %% [markdown]
# # Simple Reinforcement Learning in Tensorflow Part 2: Policy Gradient Method
# This tutorial contains a simple example of how to build a policy-gradient based agent that can solve the CartPole problem. For more information, see this [Medium post](https://medium.com/@awjuliani/super-simple-reinforcement-learning-tutorial-part-2-ded33892c724#.mtwpvfi8b).
#
# For more Reinforcement Learning algorithms, including DQN and Model-based learning in Tensorflow, see my Github repo, [DeepRL-Agents](https://github.com/awjuliani/DeepRL-Agents).
#
# Parts of this tutorial are based on code by [Andrej Karpathy](https://gist.github.com/karpathy/a4166c7fe253700972fcbc77e4ea32c5) and [korymath](https://gym.openai.com/evaluations/eval_a0aVJrGSyW892vBM04HQA).

# %%
import numpy as np
import _pickle as pickle
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ### Loading the CartPole Environment
# If you don't already have the OpenAI gym installed, use  `pip install gym` to grab it.

# %%
import gym
from gym import wrappers
env = gym.make('CartPole-v0')
env = wrappers.Monitor(env, '/tmp/cartpole-experiment-3')
# Out:
# [2017-05-25 15:51:06,900] Making new env: CartPole-v0
# [2017-05-25 15:51:06,906] Creating monitor directory /tmp/cartpole-experiment-3

# %% [markdown]
# What happens if we try running the environment with random actions? How well do we do? (Hint: not so well.)

# %%
env.reset()
# random_episodes = 0
# reward_sum = 0
# while random_episodes < 10:
#     env.render()
#     observation, reward, done, _ = env.step(np.random.randint(0,2))
#     reward_sum += reward
#     if done:
#         random_episodes += 1
#         print("Reward for this episode was:",reward_sum)
#         reward_sum = 0
#         env.reset()
# Out:
# [2017-05-25 15:51:06,912] Starting new video recorder writing to /tmp/cartpole-experiment-3/openaigym.video.0.6558.video000000.mp4
# array([-0.04197807,  0.01352341, -0.04684693, -0.01576206])

# %% [markdown]
# The goal of the task is to achieve a reward of 200 per episode. For every step the agent keeps the pole in the air, the agent recieves a +1 reward. By randomly choosing actions, our reward for each episode is only a couple dozen. Let's make that better with RL!

# %% [markdown]
# ### Setting up our Neural Network agent
# This time we will be using a Policy neural network that takes observations, passes them through a single hidden layer, and then produces a probability of choosing a left/right movement. To learn more about this network, see [Andrej Karpathy's blog on Policy Gradient networks](http://karpathy.github.io/2016/05/31/rl/).

# %%
# hyperparameters
H = 10 # number of hidden layer neurons
batch_size = 5 # every how many episodes to do a param update?
learning_rate = 1e-2 # feel free to play with this to train faster or more stably.
gamma = 0.99 # discount factor for reward

D = 4 # input dimensionality

# %%
tf.reset_default_graph()

#This defines the network as it goes from taking an observation of the environment to 
#giving a probability of chosing to the action of moving left or right.
observations = tf.placeholder(tf.float32, [None,D] , name="input_x")
W1 = tf.get_variable("W1", shape=[D, H],
           initializer=tf.contrib.layers.xavier_initializer())
layer1 = tf.nn.relu(tf.matmul(observations,W1))
W2 = tf.get_variable("W2", shape=[H, 1],
           initializer=tf.contrib.layers.xavier_initializer())
score = tf.matmul(layer1,W2)
probability = tf.nn.sigmoid(score)

#From here we define the parts of the network needed for learning a good policy.
tvars = tf.trainable_variables()
input_y = tf.placeholder(tf.float32,[None,1], name="input_y")
advantages = tf.placeholder(tf.float32,name="reward_signal")

# The loss function. This sends the weights in the direction of making actions 
# that gave good advantage (reward over time) more likely, and actions that didn't less likely.
loglik = tf.log(input_y*(input_y - probability) + (1 - input_y)*(input_y + probability))
loss = -tf.reduce_mean(loglik * advantages) 
newGrads = tf.gradients(loss,tvars)

# Once we have collected a series of gradients from multiple episodes, we apply them.
# We don't just apply gradeients after every episode in order to account for noise in the reward signal.
adam = tf.train.AdamOptimizer(learning_rate=learning_rate) # Our optimizer
W1Grad = tf.placeholder(tf.float32,name="batch_grad1") # Placeholders to send the final gradients through when we update.
W2Grad = tf.placeholder(tf.float32,name="batch_grad2")
batchGrad = [W1Grad,W2Grad]
updateGrads = adam.apply_gradients(zip(batchGrad,tvars))

# %% [markdown]
# ### Advantage function
# This function allows us to weigh the rewards our agent recieves. In the context of the Cart-Pole task, we want actions that kept the pole in the air a long time to have a large reward, and actions that contributed to the pole falling to have a decreased or negative reward. We do this by weighing the rewards from the end of the episode, with actions at the end being seen as negative, since they likely contributed to the pole falling, and the episode ending. Likewise, early actions are seen as more positive, since they weren't responsible for the pole falling.

# %%
def discount_rewards(r):
    """ take 1D float array of rewards and compute discounted reward """
    discounted_r = np.zeros_like(r)
    running_add = 0
    for t in reversed(range(0, r.size)):
        running_add = running_add * gamma + r[t]
        discounted_r[t] = running_add
    return discounted_r

# %% [markdown]
# ### Running the Agent and Environment

# %% [markdown]
# Here we run the neural network agent, and have it act in the CartPole environment.

# %% [markdown]
# As you can see, the network not only does much better than random actions, but achieves the goal of 200 points per episode, thus solving the task!

# %%
xs,hs,dlogps,drs,ys,tfps = [],[],[],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 1
total_episodes = 10000
init = tf.initialize_all_variables()

# Launch the graph
with tf.Session() as sess:
    rendering = False
    sess.run(init)
    observation = env.reset() # Obtain an initial observation of the environment

    # Reset the gradient placeholder. We will collect gradients in 
    # gradBuffer until we are ready to update our policy network. 
    gradBuffer = sess.run(tvars)
    for ix,grad in enumerate(gradBuffer):
        gradBuffer[ix] = grad * 0
    
    while episode_number <= total_episodes:
        
        # Rendering the environment slows things down, 
        # so let's only look at it once our agent is doing a good job.
#         if reward_sum/batch_size > 100 or rendering == True :
        if True:
            env.render("human")
            rendering = True
            
        # Make sure the observation is in a shape the network can handle.
        x = np.reshape(observation,[1,D])
        
        # Run the policy network and get an action to take. 
        tfprob = sess.run(probability,feed_dict={observations: x})
        action = 1 if np.random.uniform() < tfprob else 0
        
        xs.append(x) # observation
        y = 1 if action == 0 else 0 # a "fake label"
        ys.append(y)

        # step the environment and get new measurements
        observation, reward, done, info = env.step(action)
        reward_sum += reward

        drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

        if done: 
            episode_number += 1
            # stack together all inputs, hidden states, action gradients, and rewards for this episode
            epx = np.vstack(xs)
            epy = np.vstack(ys)
            epr = np.vstack(drs)
            tfp = tfps
            xs,hs,dlogps,drs,ys,tfps = [],[],[],[],[],[] # reset array memory

            # compute the discounted reward backwards through time
            discounted_epr = discount_rewards(epr)
            # size the rewards to be unit normal (helps control the gradient estimator variance)
            discounted_epr -= np.mean(discounted_epr)
            discounted_epr /= np.std(discounted_epr)
            
            # Get the gradient for this episode, and save it in the gradBuffer
            tGrad = sess.run(newGrads,feed_dict={observations: epx, input_y: epy, advantages: discounted_epr})
            for ix,grad in enumerate(tGrad):
                gradBuffer[ix] += grad
                
            # If we have completed enough episodes, then update the policy network with our gradients.
            if episode_number % batch_size == 0: 
                sess.run(updateGrads,feed_dict={W1Grad: gradBuffer[0],W2Grad:gradBuffer[1]})
                for ix,grad in enumerate(gradBuffer):
                    gradBuffer[ix] = grad * 0
                
                # Give a summary of how well our network is doing for each batch of episodes.
                running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
                print('Average reward for episode %f.  Total average reward %f.' % (reward_sum/batch_size, running_reward/batch_size))
                
                if reward_sum/batch_size > 200: 
                    print("Task solved in",episode_number,'episodes!')
                    break
                    
                reward_sum = 0
            
            observation = env.reset()

print(episode_number,'Episodes completed.')
# Out:
# WARNING:tensorflow:From <ipython-input-7-3c59ebf77625>:6: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# [2017-05-25 15:51:08,266] From <ipython-input-7-3c59ebf77625>:6: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# [2017-05-25 15:51:08,725] Starting new video recorder writing to /tmp/cartpole-experiment-3/openaigym.video.0.6558.video000001.mp4
# [2017-05-25 15:51:09,395] Starting new video recorder writing to /tmp/cartpole-experiment-3/openaigym.video.0.6558.video000008.mp4
# Average reward for episode 15.400000.  Total average reward 15.400000.
# Average reward for episode 18.200000.  Total average reward 15.428000.
# Average reward for episode 19.800000.  Total average reward 15.471720.
# Average reward for episode 17.400000.  Total average reward 15.491003.
# Average reward for episode 32.200000.  Total average reward 15.658093.
# [2017-05-25 15:51:10,425] Starting new video recorder writing to /tmp/cartpole-experiment-3/openaigym.video.0.6558.video000027.mp4
# Average reward for episode 22.800000.  Total average reward 15.729512.
# Average reward for episode 23.800000.  Total average reward 15.810217.
# Average reward for episode 20.800000.  Total average reward 15.860115.
# Average reward for episode 26.400000.  Total average reward 15.965513.
# Average reward for episode 19.200000.  Total average reward 15.997858.
# Average reward for episode 17.400000.  Total average reward 16.011880.
# Average reward for episode 31.200000.  Total average reward 16.163761.
# [2017-05-25 15:51:11,867] Starting new video recorder writing to /tmp/cartpole-experiment-3/openaigym.video.0.6558.video000064.mp4
# Average reward for episode 17.800000.  Total average reward 16.180123.
# Average reward for episode 24.600000.  Total average reward 16.264322.
# Average reward for episode 22.800000.  Total average reward 16.329679.
# Average reward for episode 22.600000.  Total average reward 16.392382.
# Average reward for episode 40.600000.  Total average reward 16.634458.
# Average reward for episode 22.200000.  Total average reward 16.690114.
# Average reward for episode 34.000000.  Total average reward 16.863213.
# Average reward for episode 38.400000.  Total average reward 17.078580.
# Average reward for episode 22.800000.  Total average reward 17.135795.
# Average reward for episode 28.800000.  Total average reward 17.252437.
# Average reward for episode 24.200000.  Total average reward 17.321912.
# [2017-05-25 15:51:14,201] Starting new video recorder writing to /tmp/cartpole-experiment-3/openaigym.video.0.6558.video000125.mp4
# Average reward for episode 18.200000.  Total average reward 17.330693.
# Average reward for episode 23.200000.  Total average reward 17.389386.
# Average reward for episode 22.800000.  Total average reward 17.443492.
# Average reward for episode 21.600000.  Total average reward 17.485057.
# Average reward for episode 19.000000.  Total average reward 17.500207.
# Average reward for episode 34.200000.  Total average reward 17.667205.
# Average reward for episode 40.200000.  Total average reward 17.892533.
# Average reward for episode 26.200000.  Total average reward 17.975607.
# Average reward for episode 23.800000.  Total average reward 18.033851.
# Average reward for episode 48.400000.  Total average reward 18.337513.
# Average reward for episode 24.200000.  Total average reward 18.396138.
# Average reward for episode 28.600000.  Total average reward 18.498176.
# Average reward for episode 39.200000.  Total average reward 18.705195.
# Average reward for episode 23.000000.  Total average reward 18.748143.
# Average reward for episode 30.600000.  Total average reward 18.866661.
# Average reward for episode 29.400000.  Total average reward 18.971995.
# Average reward for episode 35.400000.  Total average reward 19.136275.
# Average reward for episode 40.600000.  Total average reward 19.350912.
# Average reward for episode 34.000000.  Total average reward 19.497403.
# [2017-05-25 15:51:17,965] Starting new video recorder writing to /tmp/cartpole-experiment-3/openaigym.video.0.6558.video000216.mp4
# Average reward for episode 41.000000.  Total average reward 19.712429.
# Average reward for episode 30.800000.  Total average reward 19.823304.
# Average reward for episode 34.200000.  Total average reward 19.967071.
# Average reward for episode 35.000000.  Total average reward 20.117401.
# Average reward for episode 29.400000.  Total average reward 20.210227.
# Average reward for episode 29.600000.  Total average reward 20.304124.
# Average reward for episode 32.600000.  Total average reward 20.427083.
# Average reward for episode 49.800000.  Total average reward 20.720812.
# Average reward for episode 23.800000.  Total average reward 20.751604.
# Average reward for episode 50.200000.  Total average reward 21.046088.
# Average reward for episode 29.000000.  Total average reward 21.125627.
# Average reward for episode 28.600000.  Total average reward 21.200371.
# Average reward for episode 32.800000.  Total average reward 21.316367.
# Average reward for episode 43.400000.  Total average reward 21.537204.
# Average reward for episode 47.000000.  Total average reward 21.791832.
# Average reward for episode 55.400000.  Total average reward 22.127913.
# Average reward for episode 42.000000.  Total average reward 22.326634.
# Average reward for episode 37.600000.  Total average reward 22.479368.
# Average reward for episode 37.400000.  Total average reward 22.628574.
# Average reward for episode 44.200000.  Total average reward 22.844288.
# Average reward for episode 75.000000.  Total average reward 23.365846.
# Average reward for episode 70.400000.  Total average reward 23.836187.
# Average reward for episode 48.400000.  Total average reward 24.081825.
# Average reward for episode 64.000000.  Total average reward 24.481007.
# Average reward for episode 41.000000.  Total average reward 24.646197.
# [2017-05-25 15:51:24,810] Starting new video recorder writing to /tmp/cartpole-experiment-3/openaigym.video.0.6558.video000343.mp4
# Average reward for episode 52.800000.  Total average reward 24.927735.
# Average reward for episode 31.200000.  Total average reward 24.990458.
# Average reward for episode 59.000000.  Total average reward 25.330553.
# Average reward for episode 40.800000.  Total average reward 25.485247.
# Average reward for episode 59.400000.  Total average reward 25.824395.
# Average reward for episode 37.800000.  Total average reward 25.944151.
# Average reward for episode 52.600000.  Total average reward 26.210710.
# Average reward for episode 55.600000.  Total average reward 26.504602.
# Average reward for episode 61.800000.  Total average reward 26.857556.
# Average reward for episode 57.200000.  Total average reward 27.160981.
# Average reward for episode 48.800000.  Total average reward 27.377371.
# Average reward for episode 30.200000.  Total average reward 27.405597.
# Average reward for episode 58.400000.  Total average reward 27.715541.
# Average reward for episode 57.000000.  Total average reward 28.008386.
# Average reward for episode 46.000000.  Total average reward 28.188302.
# Average reward for episode 49.400000.  Total average reward 28.400419.
# Average reward for episode 45.800000.  Total average reward 28.574415.
# Average reward for episode 71.600000.  Total average reward 29.004671.
# Average reward for episode 41.600000.  Total average reward 29.130624.
# Average reward for episode 52.600000.  Total average reward 29.365318.
# Average reward for episode 36.600000.  Total average reward 29.437665.
# Average reward for episode 78.800000.  Total average reward 29.931288.
# Average reward for episode 50.600000.  Total average reward 30.137975.
# Average reward for episode 48.600000.  Total average reward 30.322595.
# Average reward for episode 72.400000.  Total average reward 30.743369.
# Average reward for episode 70.000000.  Total average reward 31.135936.
# Average reward for episode 60.800000.  Total average reward 31.432576.
# Average reward for episode 77.400000.  Total average reward 31.892251.
# Average reward for episode 79.800000.  Total average reward 32.371328.
# Average reward for episode 60.800000.  Total average reward 32.655615.
# Average reward for episode 65.800000.  Total average reward 32.987059.
# Average reward for episode 49.400000.  Total average reward 33.151188.
# Average reward for episode 50.800000.  Total average reward 33.327676.
# Average reward for episode 90.600000.  Total average reward 33.900399.
# [2017-05-25 15:51:37,023] Starting new video recorder writing to /tmp/cartpole-experiment-3/openaigym.video.0.6558.video000512.mp4
# Average reward for episode 57.400000.  Total average reward 34.135395.
# Average reward for episode 53.400000.  Total average reward 34.328041.
# Average reward for episode 88.200000.  Total average reward 34.866761.
# Average reward for episode 46.600000.  Total average reward 34.984093.
# Average reward for episode 105.000000.  Total average reward 35.684252.
# Average reward for episode 51.000000.  Total average reward 35.837410.
# Average reward for episode 61.200000.  Total average reward 36.091036.
# Average reward for episode 81.000000.  Total average reward 36.540125.
# Average reward for episode 104.000000.  Total average reward 37.214724.
# Average reward for episode 74.000000.  Total average reward 37.582577.
# Average reward for episode 64.400000.  Total average reward 37.850751.
# Average reward for episode 128.800000.  Total average reward 38.760244.
# Average reward for episode 89.000000.  Total average reward 39.262641.
# Average reward for episode 66.400000.  Total average reward 39.534015.
# Average reward for episode 83.400000.  Total average reward 39.972675.
# Average reward for episode 70.800000.  Total average reward 40.280948.
# Average reward for episode 61.400000.  Total average reward 40.492138.
# Average reward for episode 104.200000.  Total average reward 41.129217.
# Average reward for episode 98.800000.  Total average reward 41.705925.
# Average reward for episode 86.400000.  Total average reward 42.152866.
# Average reward for episode 108.200000.  Total average reward 42.813337.
# Average reward for episode 119.200000.  Total average reward 43.577204.
# Average reward for episode 84.800000.  Total average reward 43.989432.
# Average reward for episode 108.000000.  Total average reward 44.629537.
# Average reward for episode 104.400000.  Total average reward 45.227242.
# Average reward for episode 126.200000.  Total average reward 46.036970.
# Average reward for episode 114.200000.  Total average reward 46.718600.
# Average reward for episode 73.800000.  Total average reward 46.989414.
# Average reward for episode 100.000000.  Total average reward 47.519520.
# Average reward for episode 141.400000.  Total average reward 48.458324.
# Average reward for episode 154.600000.  Total average reward 49.519741.
# Average reward for episode 103.200000.  Total average reward 50.056544.
# Average reward for episode 137.400000.  Total average reward 50.929978.
# Average reward for episode 124.800000.  Total average reward 51.668679.
# Average reward for episode 65.000000.  Total average reward 51.801992.
# Average reward for episode 125.200000.  Total average reward 52.535972.
# Average reward for episode 159.800000.  Total average reward 53.608612.
# Average reward for episode 151.800000.  Total average reward 54.590526.
# Average reward for episode 116.400000.  Total average reward 55.208621.
# Average reward for episode 118.600000.  Total average reward 55.842535.
# Average reward for episode 128.800000.  Total average reward 56.572109.
# Average reward for episode 127.000000.  Total average reward 57.276388.
# Average reward for episode 90.000000.  Total average reward 57.603624.
# Average reward for episode 104.000000.  Total average reward 58.067588.
# [2017-05-25 15:52:03,681] Starting new video recorder writing to /tmp/cartpole-experiment-3/openaigym.video.0.6558.video000729.mp4
# Average reward for episode 198.000000.  Total average reward 59.466912.
# Average reward for episode 170.000000.  Total average reward 60.572243.
# Average reward for episode 161.400000.  Total average reward 61.580521.
# Average reward for episode 132.000000.  Total average reward 62.284715.
# Average reward for episode 165.600000.  Total average reward 63.317868.
# Average reward for episode 68.000000.  Total average reward 63.364690.
# Average reward for episode 144.800000.  Total average reward 64.179043.
# Average reward for episode 148.400000.  Total average reward 65.021252.
# Average reward for episode 154.000000.  Total average reward 65.911040.
# Average reward for episode 185.400000.  Total average reward 67.105929.
# Average reward for episode 158.200000.  Total average reward 68.016870.
# Average reward for episode 192.600000.  Total average reward 69.262701.
# Average reward for episode 200.000000.  Total average reward 70.570074.
# Average reward for episode 191.400000.  Total average reward 71.778374.
# Average reward for episode 107.200000.  Total average reward 72.132590.
# Average reward for episode 135.600000.  Total average reward 72.767264.
# Average reward for episode 170.600000.  Total average reward 73.745591.
# Average reward for episode 197.600000.  Total average reward 74.984135.
# Average reward for episode 172.000000.  Total average reward 75.954294.
# Average reward for episode 161.000000.  Total average reward 76.804751.
# Average reward for episode 182.000000.  Total average reward 77.856704.
# Average reward for episode 187.800000.  Total average reward 78.956137.
# Average reward for episode 200.000000.  Total average reward 80.166575.
# Average reward for episode 200.000000.  Total average reward 81.364909.
# Average reward for episode 165.400000.  Total average reward 82.205260.
# Average reward for episode 185.800000.  Total average reward 83.241208.
# Average reward for episode 186.200000.  Total average reward 84.270796.
# Average reward for episode 200.000000.  Total average reward 85.428088.
# Average reward for episode 199.200000.  Total average reward 86.565807.
# Average reward for episode 161.200000.  Total average reward 87.312149.
# Average reward for episode 198.200000.  Total average reward 88.421027.
# Average reward for episode 171.000000.  Total average reward 89.246817.
# Average reward for episode 194.800000.  Total average reward 90.302349.
# Average reward for episode 187.200000.  Total average reward 91.271325.
# Average reward for episode 182.800000.  Total average reward 92.186612.
# Average reward for episode 197.800000.  Total average reward 93.242746.
# Average reward for episode 200.000000.  Total average reward 94.310318.
# Average reward for episode 198.600000.  Total average reward 95.353215.
# Average reward for episode 192.200000.  Total average reward 96.321683.
# Average reward for episode 184.600000.  Total average reward 97.204466.
# Average reward for episode 197.400000.  Total average reward 98.206422.
# Average reward for episode 200.000000.  Total average reward 99.224357.
# Average reward for episode 183.200000.  Total average reward 100.064114.
# Average reward for episode 156.600000.  Total average reward 100.629473.
# Average reward for episode 197.000000.  Total average reward 101.593178.
# Average reward for episode 180.200000.  Total average reward 102.379246.
# Average reward for episode 187.200000.  Total average reward 103.227454.
# Average reward for episode 167.200000.  Total average reward 103.867179.
# Average reward for episode 175.400000.  Total average reward 104.582507.
# Average reward for episode 168.800000.  Total average reward 105.224682.
# Average reward for episode 158.000000.  Total average reward 105.752436.
# Average reward for episode 182.400000.  Total average reward 106.518911.
# Average reward for episode 163.400000.  Total average reward 107.087722.
# Average reward for episode 169.600000.  Total average reward 107.712845.
# [2017-05-25 15:53:03,474] Starting new video recorder writing to /tmp/cartpole-experiment-3/openaigym.video.0.6558.video001000.mp4
# Average reward for episode 178.600000.  Total average reward 108.421716.
# Average reward for episode 190.400000.  Total average reward 109.241499.
# Average reward for episode 166.000000.  Total average reward 109.809084.
# Average reward for episode 178.200000.  Total average reward 110.492993.
# Average reward for episode 185.400000.  Total average reward 111.242063.
# Average reward for episode 185.200000.  Total average reward 111.981643.
# Average reward for episode 177.400000.  Total average reward 112.635826.
# Average reward for episode 190.600000.  Total average reward 113.415468.
# Average reward for episode 170.000000.  Total average reward 113.981313.
# Average reward for episode 200.000000.  Total average reward 114.841500.
# Average reward for episode 163.200000.  Total average reward 115.325085.
# Average reward for episode 178.800000.  Total average reward 115.959834.
# Average reward for episode 162.000000.  Total average reward 116.420236.
# Average reward for episode 174.400000.  Total average reward 117.000034.
# Average reward for episode 199.200000.  Total average reward 117.822033.
# Average reward for episode 160.200000.  Total average reward 118.245813.
# Average reward for episode 184.800000.  Total average reward 118.911355.
# Average reward for episode 180.200000.  Total average reward 119.524241.
# Average reward for episode 175.200000.  Total average reward 120.080999.
# Average reward for episode 183.800000.  Total average reward 120.718189.
# Average reward for episode 153.400000.  Total average reward 121.045007.
# Average reward for episode 176.800000.  Total average reward 121.602557.
# Average reward for episode 151.000000.  Total average reward 121.896531.
# Average reward for episode 182.000000.  Total average reward 122.497566.
# Average reward for episode 193.200000.  Total average reward 123.204590.
# Average reward for episode 193.800000.  Total average reward 123.910545.
# Average reward for episode 187.600000.  Total average reward 124.547439.
# Average reward for episode 171.200000.  Total average reward 125.013965.
# Average reward for episode 195.800000.  Total average reward 125.721825.
# Average reward for episode 198.600000.  Total average reward 126.450607.
# Average reward for episode 191.200000.  Total average reward 127.098101.
# Average reward for episode 168.800000.  Total average reward 127.515120.
# Average reward for episode 166.800000.  Total average reward 127.907969.
# Average reward for episode 164.000000.  Total average reward 128.268889.
# Average reward for episode 177.200000.  Total average reward 128.758200.
# Average reward for episode 195.800000.  Total average reward 129.428618.
# Average reward for episode 186.800000.  Total average reward 130.002332.
# Average reward for episode 174.800000.  Total average reward 130.450309.
# Average reward for episode 200.000000.  Total average reward 131.145805.
# Average reward for episode 191.000000.  Total average reward 131.744347.
# Average reward for episode 187.600000.  Total average reward 132.302904.
# Average reward for episode 161.800000.  Total average reward 132.597875.
# Average reward for episode 175.800000.  Total average reward 133.029896.
# Average reward for episode 159.200000.  Total average reward 133.291597.
# Average reward for episode 186.800000.  Total average reward 133.826681.
# Average reward for episode 200.000000.  Total average reward 134.488414.
# Average reward for episode 153.200000.  Total average reward 134.675530.
# Average reward for episode 179.800000.  Total average reward 135.126775.
# Average reward for episode 200.000000.  Total average reward 135.775507.
# Average reward for episode 174.800000.  Total average reward 136.165752.
# Average reward for episode 200.000000.  Total average reward 136.804095.
# Average reward for episode 200.000000.  Total average reward 137.436054.
# Average reward for episode 200.000000.  Total average reward 138.061693.
# Average reward for episode 200.000000.  Total average reward 138.681076.
# Average reward for episode 200.000000.  Total average reward 139.294265.
# Average reward for episode 200.000000.  Total average reward 139.901323.
# Average reward for episode 200.000000.  Total average reward 140.502310.
# Average reward for episode 200.000000.  Total average reward 141.097286.
# Average reward for episode 200.000000.  Total average reward 141.686314.
# Average reward for episode 200.000000.  Total average reward 142.269450.
# Average reward for episode 200.000000.  Total average reward 142.846756.
# Average reward for episode 194.400000.  Total average reward 143.362288.
# Average reward for episode 169.800000.  Total average reward 143.626665.
# Average reward for episode 200.000000.  Total average reward 144.190399.
# Average reward for episode 200.000000.  Total average reward 144.748495.
# Average reward for episode 191.200000.  Total average reward 145.213010.
# Average reward for episode 200.000000.  Total average reward 145.760880.
# Average reward for episode 188.200000.  Total average reward 146.185271.
# Average reward for episode 183.000000.  Total average reward 146.553418.
# Average reward for episode 200.000000.  Total average reward 147.087884.
# Average reward for episode 194.200000.  Total average reward 147.559005.
# Average reward for episode 200.000000.  Total average reward 148.083415.
# Average reward for episode 172.800000.  Total average reward 148.330581.
# Average reward for episode 200.000000.  Total average reward 148.847275.
# Average reward for episode 200.000000.  Total average reward 149.358802.
# Average reward for episode 200.000000.  Total average reward 149.865214.
# Average reward for episode 194.600000.  Total average reward 150.312562.
# Average reward for episode 200.000000.  Total average reward 150.809437.
# Average reward for episode 200.000000.  Total average reward 151.301342.
# Average reward for episode 200.000000.  Total average reward 151.788329.
# Average reward for episode 200.000000.  Total average reward 152.270446.
# Average reward for episode 200.000000.  Total average reward 152.747741.
# Average reward for episode 155.400000.  Total average reward 152.774264.
# Average reward for episode 200.000000.  Total average reward 153.246521.
# Average reward for episode 200.000000.  Total average reward 153.714056.
# Average reward for episode 191.400000.  Total average reward 154.090915.
# Average reward for episode 200.000000.  Total average reward 154.550006.
# Average reward for episode 200.000000.  Total average reward 155.004506.
# Average reward for episode 195.000000.  Total average reward 155.404461.
# Average reward for episode 185.400000.  Total average reward 155.704416.
# Average reward for episode 195.400000.  Total average reward 156.101372.
# Average reward for episode 200.000000.  Total average reward 156.540359.
# Average reward for episode 200.000000.  Total average reward 156.974955.
# Average reward for episode 195.000000.  Total average reward 157.355205.
# Average reward for episode 186.800000.  Total average reward 157.649653.
# Average reward for episode 200.000000.  Total average reward 158.073157.
# Average reward for episode 200.000000.  Total average reward 158.492425.
# Average reward for episode 200.000000.  Total average reward 158.907501.
# Average reward for episode 198.000000.  Total average reward 159.298426.
# Average reward for episode 200.000000.  Total average reward 159.705442.
# Average reward for episode 200.000000.  Total average reward 160.108387.
# Average reward for episode 200.000000.  Total average reward 160.507303.
# Average reward for episode 200.000000.  Total average reward 160.902230.
# Average reward for episode 200.000000.  Total average reward 161.293208.
# Average reward for episode 200.000000.  Total average reward 161.680276.
# Average reward for episode 200.000000.  Total average reward 162.063473.
# Average reward for episode 200.000000.  Total average reward 162.442839.
# Average reward for episode 200.000000.  Total average reward 162.818410.
# Average reward for episode 200.000000.  Total average reward 163.190226.
# Average reward for episode 200.000000.  Total average reward 163.558324.
# Average reward for episode 190.400000.  Total average reward 163.826741.
# Average reward for episode 186.400000.  Total average reward 164.052473.
# Average reward for episode 200.000000.  Total average reward 164.411948.
# Average reward for episode 200.000000.  Total average reward 164.767829.
# Average reward for episode 192.200000.  Total average reward 165.042151.
# Average reward for episode 194.400000.  Total average reward 165.335729.
# Average reward for episode 200.000000.  Total average reward 165.682372.
# Average reward for episode 199.400000.  Total average reward 166.019548.
# Average reward for episode 192.200000.  Total average reward 166.281353.
# Average reward for episode 195.200000.  Total average reward 166.570539.
# Average reward for episode 181.200000.  Total average reward 166.716834.
# Average reward for episode 200.000000.  Total average reward 167.049665.
# Average reward for episode 185.000000.  Total average reward 167.229169.
# Average reward for episode 200.000000.  Total average reward 167.556877.
# Average reward for episode 200.000000.  Total average reward 167.881308.
# Average reward for episode 194.800000.  Total average reward 168.150495.
# Average reward for episode 200.000000.  Total average reward 168.468990.
# Average reward for episode 194.800000.  Total average reward 168.732300.
# Average reward for episode 195.800000.  Total average reward 169.002977.
# Average reward for episode 195.400000.  Total average reward 169.266948.
# Average reward for episode 196.800000.  Total average reward 169.542278.
# Average reward for episode 195.000000.  Total average reward 169.796855.
# Average reward for episode 184.000000.  Total average reward 169.938887.
# Average reward for episode 200.000000.  Total average reward 170.239498.
# Average reward for episode 200.000000.  Total average reward 170.537103.
# Average reward for episode 189.000000.  Total average reward 170.721732.
# Average reward for episode 189.600000.  Total average reward 170.910515.
# Average reward for episode 198.200000.  Total average reward 171.183409.
# Average reward for episode 200.000000.  Total average reward 171.471575.
# Average reward for episode 187.800000.  Total average reward 171.634860.
# Average reward for episode 200.000000.  Total average reward 171.918511.
# Average reward for episode 200.000000.  Total average reward 172.199326.
# Average reward for episode 200.000000.  Total average reward 172.477333.
# Average reward for episode 198.400000.  Total average reward 172.736559.
# Average reward for episode 196.400000.  Total average reward 172.973194.
# Average reward for episode 200.000000.  Total average reward 173.243462.
# Average reward for episode 180.200000.  Total average reward 173.313027.
# Average reward for episode 188.800000.  Total average reward 173.467897.
# Average reward for episode 200.000000.  Total average reward 173.733218.
# Average reward for episode 200.000000.  Total average reward 173.995886.
# Average reward for episode 200.000000.  Total average reward 174.255927.
# Average reward for episode 200.000000.  Total average reward 174.513368.
# Average reward for episode 198.800000.  Total average reward 174.756234.
# Average reward for episode 197.200000.  Total average reward 174.980672.
# Average reward for episode 200.000000.  Total average reward 175.230865.
# Average reward for episode 200.000000.  Total average reward 175.478556.
# Average reward for episode 195.200000.  Total average reward 175.675771.
# Average reward for episode 200.000000.  Total average reward 175.919013.
# Average reward for episode 200.000000.  Total average reward 176.159823.
# Average reward for episode 200.000000.  Total average reward 176.398225.
# Average reward for episode 191.200000.  Total average reward 176.546242.
# Average reward for episode 200.000000.  Total average reward 176.780780.
# Average reward for episode 200.000000.  Total average reward 177.012972.
# Average reward for episode 200.000000.  Total average reward 177.242842.
# Average reward for episode 191.400000.  Total average reward 177.384414.
# Average reward for episode 183.400000.  Total average reward 177.444570.
# Average reward for episode 200.000000.  Total average reward 177.670124.
# Average reward for episode 200.000000.  Total average reward 177.893423.
# Average reward for episode 200.000000.  Total average reward 178.114489.
# Average reward for episode 198.400000.  Total average reward 178.317344.
# Average reward for episode 190.200000.  Total average reward 178.436170.
# Average reward for episode 199.200000.  Total average reward 178.643809.
# Average reward for episode 199.200000.  Total average reward 178.849371.
# Average reward for episode 200.000000.  Total average reward 179.060877.
# Average reward for episode 200.000000.  Total average reward 179.270268.
# Average reward for episode 196.000000.  Total average reward 179.437565.
# Average reward for episode 200.000000.  Total average reward 179.643190.
# Average reward for episode 200.000000.  Total average reward 179.846758.
# Average reward for episode 200.000000.  Total average reward 180.048290.
# Average reward for episode 195.600000.  Total average reward 180.203807.
# Average reward for episode 200.000000.  Total average reward 180.401769.
# Average reward for episode 200.000000.  Total average reward 180.597752.
# Average reward for episode 200.000000.  Total average reward 180.791774.
# Average reward for episode 197.400000.  Total average reward 180.957856.
# Average reward for episode 200.000000.  Total average reward 181.148278.
# Average reward for episode 196.600000.  Total average reward 181.302795.
# Average reward for episode 200.000000.  Total average reward 181.489767.
# Average reward for episode 200.000000.  Total average reward 181.674869.
# Average reward for episode 200.000000.  Total average reward 181.858121.
# Average reward for episode 200.000000.  Total average reward 182.039539.
# Average reward for episode 200.000000.  Total average reward 182.219144.
# Average reward for episode 200.000000.  Total average reward 182.396953.
# Average reward for episode 200.000000.  Total average reward 182.572983.
# Average reward for episode 200.000000.  Total average reward 182.747253.
# Average reward for episode 200.000000.  Total average reward 182.919781.
# Average reward for episode 200.000000.  Total average reward 183.090583.
# Average reward for episode 200.000000.  Total average reward 183.259677.
# Average reward for episode 167.800000.  Total average reward 183.105080.
# Average reward for episode 200.000000.  Total average reward 183.274030.
# Average reward for episode 196.000000.  Total average reward 183.401289.
# [2017-05-25 15:57:01,721] Starting new video recorder writing to /tmp/cartpole-experiment-3/openaigym.video.0.6558.video002000.mp4
# Average reward for episode 200.000000.  Total average reward 183.567276.
# Average reward for episode 200.000000.  Total average reward 183.731604.
# Average reward for episode 200.000000.  Total average reward 183.894288.
# Average reward for episode 195.800000.  Total average reward 184.013345.
# Average reward for episode 200.000000.  Total average reward 184.173211.
# Average reward for episode 200.000000.  Total average reward 184.331479.
# Average reward for episode 200.000000.  Total average reward 184.488164.
# Average reward for episode 188.000000.  Total average reward 184.523283.
# Average reward for episode 200.000000.  Total average reward 184.678050.
# Average reward for episode 200.000000.  Total average reward 184.831269.
# Average reward for episode 200.000000.  Total average reward 184.982957.
# Average reward for episode 200.000000.  Total average reward 185.133127.
# Average reward for episode 200.000000.  Total average reward 185.281796.
# Average reward for episode 200.000000.  Total average reward 185.428978.
# Average reward for episode 200.000000.  Total average reward 185.574688.
# Average reward for episode 200.000000.  Total average reward 185.718941.
# Average reward for episode 187.200000.  Total average reward 185.733752.
# Average reward for episode 200.000000.  Total average reward 185.876414.
# Average reward for episode 200.000000.  Total average reward 186.017650.
# Average reward for episode 200.000000.  Total average reward 186.157474.
# Average reward for episode 200.000000.  Total average reward 186.295899.
# Average reward for episode 171.800000.  Total average reward 186.150940.
# Average reward for episode 200.000000.  Total average reward 186.289431.
# Average reward for episode 200.000000.  Total average reward 186.426536.
# Average reward for episode 200.000000.  Total average reward 186.562271.
# Average reward for episode 200.000000.  Total average reward 186.696648.
# Average reward for episode 200.000000.  Total average reward 186.829682.
# Average reward for episode 189.200000.  Total average reward 186.853385.
# Average reward for episode 200.000000.  Total average reward 186.984851.
# Average reward for episode 200.000000.  Total average reward 187.115002.
# Average reward for episode 151.200000.  Total average reward 186.755852.
# Average reward for episode 200.000000.  Total average reward 186.888294.
# Average reward for episode 188.600000.  Total average reward 186.905411.
# Average reward for episode 200.000000.  Total average reward 187.036357.
# Average reward for episode 200.000000.  Total average reward 187.165993.
# Average reward for episode 190.400000.  Total average reward 187.198333.
# Average reward for episode 200.000000.  Total average reward 187.326350.
# Average reward for episode 200.000000.  Total average reward 187.453087.
# Average reward for episode 200.000000.  Total average reward 187.578556.
# Average reward for episode 200.000000.  Total average reward 187.702770.
# Average reward for episode 200.000000.  Total average reward 187.825742.
# Average reward for episode 200.000000.  Total average reward 187.947485.
# Average reward for episode 200.000000.  Total average reward 188.068010.
# Average reward for episode 200.000000.  Total average reward 188.187330.
# Average reward for episode 200.000000.  Total average reward 188.305457.
# Average reward for episode 200.000000.  Total average reward 188.422402.
# Average reward for episode 200.000000.  Total average reward 188.538178.
# Average reward for episode 200.000000.  Total average reward 188.652796.
# Average reward for episode 200.000000.  Total average reward 188.766268.
# Average reward for episode 200.000000.  Total average reward 188.878606.
# Average reward for episode 200.000000.  Total average reward 188.989820.
# Average reward for episode 197.800000.  Total average reward 189.077921.
# Average reward for episode 200.000000.  Total average reward 189.187142.
# Average reward for episode 200.000000.  Total average reward 189.295271.
# Average reward for episode 200.000000.  Total average reward 189.402318.
# Average reward for episode 200.000000.  Total average reward 189.508295.
# Average reward for episode 200.000000.  Total average reward 189.613212.
# Average reward for episode 200.000000.  Total average reward 189.717080.
# Average reward for episode 200.000000.  Total average reward 189.819909.
# Average reward for episode 200.000000.  Total average reward 189.921710.
# Average reward for episode 200.000000.  Total average reward 190.022493.
# Average reward for episode 196.000000.  Total average reward 190.082268.
# Average reward for episode 199.000000.  Total average reward 190.171445.
# Average reward for episode 200.000000.  Total average reward 190.269731.
# Average reward for episode 200.000000.  Total average reward 190.367034.
# Average reward for episode 200.000000.  Total average reward 190.463363.
# Average reward for episode 200.000000.  Total average reward 190.558730.
# Average reward for episode 200.000000.  Total average reward 190.653142.
# Average reward for episode 198.000000.  Total average reward 190.726611.
# Average reward for episode 200.000000.  Total average reward 190.819345.
# Average reward for episode 200.000000.  Total average reward 190.911151.
# Average reward for episode 200.000000.  Total average reward 191.002040.
# Average reward for episode 200.000000.  Total average reward 191.092019.
# Average reward for episode 200.000000.  Total average reward 191.181099.
# Average reward for episode 190.400000.  Total average reward 191.173288.
# Average reward for episode 200.000000.  Total average reward 191.261555.
# Average reward for episode 200.000000.  Total average reward 191.348940.
# Average reward for episode 200.000000.  Total average reward 191.435450.
# Average reward for episode 200.000000.  Total average reward 191.521096.
# Average reward for episode 200.000000.  Total average reward 191.605885.
# Average reward for episode 200.000000.  Total average reward 191.689826.
# Average reward for episode 200.000000.  Total average reward 191.772928.
# Average reward for episode 200.000000.  Total average reward 191.855198.
# Average reward for episode 200.000000.  Total average reward 191.936647.
# Average reward for episode 200.000000.  Total average reward 192.017280.
# Average reward for episode 200.000000.  Total average reward 192.097107.
# Average reward for episode 200.000000.  Total average reward 192.176136.
# Average reward for episode 200.000000.  Total average reward 192.254375.
# Average reward for episode 200.000000.  Total average reward 192.331831.
# Average reward for episode 200.000000.  Total average reward 192.408513.
# Average reward for episode 200.000000.  Total average reward 192.484428.
# Average reward for episode 200.000000.  Total average reward 192.559583.
# Average reward for episode 200.000000.  Total average reward 192.633988.
# Average reward for episode 200.000000.  Total average reward 192.707648.
# Average reward for episode 200.000000.  Total average reward 192.780571.
# Average reward for episode 200.000000.  Total average reward 192.852765.
# Average reward for episode 200.000000.  Total average reward 192.924238.
# Average reward for episode 196.600000.  Total average reward 192.960995.
# Average reward for episode 200.000000.  Total average reward 193.031385.
# Average reward for episode 200.000000.  Total average reward 193.101072.
# Average reward for episode 200.000000.  Total average reward 193.170061.
# Average reward for episode 193.200000.  Total average reward 193.170360.
# Average reward for episode 200.000000.  Total average reward 193.238657.
# Average reward for episode 200.000000.  Total average reward 193.306270.
# Average reward for episode 200.000000.  Total average reward 193.373207.
# Average reward for episode 200.000000.  Total average reward 193.439475.
# Average reward for episode 177.000000.  Total average reward 193.275081.
# Average reward for episode 200.000000.  Total average reward 193.342330.
# Average reward for episode 200.000000.  Total average reward 193.408906.
# Average reward for episode 192.200000.  Total average reward 193.396817.
# Average reward for episode 200.000000.  Total average reward 193.462849.
# Average reward for episode 200.000000.  Total average reward 193.528221.
# Average reward for episode 175.000000.  Total average reward 193.342939.
# Average reward for episode 200.000000.  Total average reward 193.409509.
# Average reward for episode 200.000000.  Total average reward 193.475414.
# Average reward for episode 200.000000.  Total average reward 193.540660.
# Average reward for episode 197.000000.  Total average reward 193.575253.
# Average reward for episode 200.000000.  Total average reward 193.639501.
# Average reward for episode 200.000000.  Total average reward 193.703106.
# Average reward for episode 200.000000.  Total average reward 193.766075.
# Average reward for episode 200.000000.  Total average reward 193.828414.
# Average reward for episode 195.200000.  Total average reward 193.842130.
# Average reward for episode 200.000000.  Total average reward 193.903709.
# Average reward for episode 200.000000.  Total average reward 193.964671.
# Average reward for episode 200.000000.  Total average reward 194.025025.
# Average reward for episode 200.000000.  Total average reward 194.084774.
# Average reward for episode 200.000000.  Total average reward 194.143927.
# Average reward for episode 200.000000.  Total average reward 194.202487.
# Average reward for episode 200.000000.  Total average reward 194.260463.
# Average reward for episode 182.200000.  Total average reward 194.139858.
# Average reward for episode 200.000000.  Total average reward 194.198459.
# Average reward for episode 200.000000.  Total average reward 194.256475.
# Average reward for episode 200.000000.  Total average reward 194.313910.
# Average reward for episode 192.600000.  Total average reward 194.296771.
# Average reward for episode 200.000000.  Total average reward 194.353803.
# Average reward for episode 196.400000.  Total average reward 194.374265.
# Average reward for episode 200.000000.  Total average reward 194.430523.
# Average reward for episode 200.000000.  Total average reward 194.486217.
# Average reward for episode 197.600000.  Total average reward 194.517355.
# Average reward for episode 200.000000.  Total average reward 194.572182.
# Average reward for episode 200.000000.  Total average reward 194.626460.
# Average reward for episode 200.000000.  Total average reward 194.680195.
# Average reward for episode 195.800000.  Total average reward 194.691393.
# Average reward for episode 200.000000.  Total average reward 194.744479.
# Average reward for episode 193.800000.  Total average reward 194.735035.
# Average reward for episode 197.600000.  Total average reward 194.763684.
# Average reward for episode 191.000000.  Total average reward 194.726047.
# Average reward for episode 200.000000.  Total average reward 194.778787.
# Average reward for episode 198.600000.  Total average reward 194.816999.
# Average reward for episode 200.000000.  Total average reward 194.868829.
# Average reward for episode 196.200000.  Total average reward 194.882141.
# Average reward for episode 198.600000.  Total average reward 194.919319.
# Average reward for episode 200.000000.  Total average reward 194.970126.
# Average reward for episode 200.000000.  Total average reward 195.020425.
# Average reward for episode 194.000000.  Total average reward 195.010221.
# Average reward for episode 193.600000.  Total average reward 194.996118.
# Average reward for episode 195.000000.  Total average reward 194.996157.
# Average reward for episode 197.000000.  Total average reward 195.016196.
# Average reward for episode 183.400000.  Total average reward 194.900034.
# Average reward for episode 190.200000.  Total average reward 194.853033.
# Average reward for episode 188.200000.  Total average reward 194.786503.
# Average reward for episode 200.000000.  Total average reward 194.838638.
# Average reward for episode 190.800000.  Total average reward 194.798252.
# Average reward for episode 200.000000.  Total average reward 194.850269.
# Average reward for episode 187.600000.  Total average reward 194.777766.
# Average reward for episode 200.000000.  Total average reward 194.829989.
# Average reward for episode 200.000000.  Total average reward 194.881689.
# Average reward for episode 192.800000.  Total average reward 194.860872.
# Average reward for episode 176.400000.  Total average reward 194.676263.
# Average reward for episode 196.800000.  Total average reward 194.697501.
# Average reward for episode 186.200000.  Total average reward 194.612526.
# Average reward for episode 196.800000.  Total average reward 194.634400.
# Average reward for episode 186.400000.  Total average reward 194.552056.
# Average reward for episode 195.600000.  Total average reward 194.562536.
# Average reward for episode 182.400000.  Total average reward 194.440910.
# Average reward for episode 199.400000.  Total average reward 194.490501.
# Average reward for episode 192.400000.  Total average reward 194.469596.
# Average reward for episode 189.200000.  Total average reward 194.416900.
# Average reward for episode 200.000000.  Total average reward 194.472731.
# Average reward for episode 200.000000.  Total average reward 194.528004.
# Average reward for episode 199.800000.  Total average reward 194.580724.
# Average reward for episode 180.200000.  Total average reward 194.436917.
# Average reward for episode 194.400000.  Total average reward 194.436548.
# Average reward for episode 200.000000.  Total average reward 194.492182.
# Average reward for episode 200.000000.  Total average reward 194.547260.
# Average reward for episode 174.000000.  Total average reward 194.341788.
# Average reward for episode 197.000000.  Total average reward 194.368370.
# Average reward for episode 175.800000.  Total average reward 194.182686.
# Average reward for episode 190.800000.  Total average reward 194.148859.
# Average reward for episode 192.600000.  Total average reward 194.133371.
# Average reward for episode 186.800000.  Total average reward 194.060037.
# Average reward for episode 200.000000.  Total average reward 194.119437.
# Average reward for episode 193.400000.  Total average reward 194.112242.
# Average reward for episode 189.600000.  Total average reward 194.067120.
# Average reward for episode 194.200000.  Total average reward 194.068449.
# Average reward for episode 200.000000.  Total average reward 194.127764.
# Average reward for episode 156.200000.  Total average reward 193.748486.
# Average reward for episode 188.200000.  Total average reward 193.693002.
# Average reward for episode 200.000000.  Total average reward 193.756072.
# Average reward for episode 192.400000.  Total average reward 193.742511.
# [2017-05-25 16:00:59,994] Starting new video recorder writing to /tmp/cartpole-experiment-3/openaigym.video.0.6558.video003000.mp4
# Average reward for episode 200.000000.  Total average reward 193.805086.
# Average reward for episode 189.800000.  Total average reward 193.765035.
# Average reward for episode 200.000000.  Total average reward 193.827385.
# Average reward for episode 200.000000.  Total average reward 193.889111.
# Average reward for episode 196.800000.  Total average reward 193.918220.
# Average reward for episode 193.200000.  Total average reward 193.911037.
# Average reward for episode 200.000000.  Total average reward 193.971927.
# Average reward for episode 200.000000.  Total average reward 194.032208.
# Average reward for episode 200.000000.  Total average reward 194.091886.
# Average reward for episode 200.000000.  Total average reward 194.150967.
# Average reward for episode 200.000000.  Total average reward 194.209457.
# Average reward for episode 185.600000.  Total average reward 194.123363.
# Average reward for episode 184.000000.  Total average reward 194.022129.
# Average reward for episode 200.000000.  Total average reward 194.081908.
# Average reward for episode 195.400000.  Total average reward 194.095089.
# Average reward for episode 200.000000.  Total average reward 194.154138.
# Average reward for episode 200.000000.  Total average reward 194.212596.
# Average reward for episode 200.000000.  Total average reward 194.270470.
# Average reward for episode 200.000000.  Total average reward 194.327766.
# Average reward for episode 200.000000.  Total average reward 194.384488.
# Average reward for episode 194.600000.  Total average reward 194.386643.
# Average reward for episode 198.200000.  Total average reward 194.424777.
# Average reward for episode 200.000000.  Total average reward 194.480529.
# Average reward for episode 196.600000.  Total average reward 194.501724.
# Average reward for episode 200.000000.  Total average reward 194.556706.
# Average reward for episode 200.000000.  Total average reward 194.611139.
# Average reward for episode 200.000000.  Total average reward 194.665028.
# Average reward for episode 200.000000.  Total average reward 194.718378.
# Average reward for episode 199.400000.  Total average reward 194.765194.
# Average reward for episode 198.800000.  Total average reward 194.805542.
# Average reward for episode 200.000000.  Total average reward 194.857487.
# Average reward for episode 200.000000.  Total average reward 194.908912.
# Average reward for episode 191.200000.  Total average reward 194.871823.
# Average reward for episode 195.600000.  Total average reward 194.879104.
# ...
# Average reward for episode 200.000000.  Total average reward 199.700548.
# Average reward for episode 182.800000.  Total average reward 199.531543.
# Average reward for episode 200.000000.  Total average reward 199.536227.
# Average reward for episode 200.000000.  Total average reward 199.540865.
# Average reward for episode 197.000000.  Total average reward 199.515456.
# Average reward for episode 200.000000.  Total average reward 199.520302.
# Average reward for episode 200.000000.  Total average reward 199.525099.
# Average reward for episode 200.000000.  Total average reward 199.529848.
# Average reward for episode 198.400000.  Total average reward 199.518549.
# Average reward for episode 200.000000.  Total average reward 199.523364.
# Average reward for episode 198.400000.  Total average reward 199.512130.
# Average reward for episode 200.000000.  Total average reward 199.517009.
# Average reward for episode 200.000000.  Total average reward 199.521839.
# Average reward for episode 185.000000.  Total average reward 199.376620.
# [2017-05-25 16:25:08,074] Starting new video recorder writing to /tmp/cartpole-experiment-3/openaigym.video.0.6558.video009000.mp4
# Average reward for episode 200.000000.  Total average reward 199.382854.
# Average reward for episode 200.000000.  Total average reward 199.389026.
# Average reward for episode 194.200000.  Total average reward 199.337135.
# Average reward for episode 200.000000.  Total average reward 199.343764.
# Average reward for episode 200.000000.  Total average reward 199.350326.
# Average reward for episode 200.000000.  Total average reward 199.356823.
# Average reward for episode 197.600000.  Total average reward 199.339255.
# Average reward for episode 200.000000.  Total average reward 199.345862.
# Average reward for episode 198.800000.  Total average reward 199.340404.
# Average reward for episode 199.000000.  Total average reward 199.337000.
# Average reward for episode 189.600000.  Total average reward 199.239630.
# Average reward for episode 195.400000.  Total average reward 199.201233.
# Average reward for episode 200.000000.  Total average reward 199.209221.
# Average reward for episode 200.000000.  Total average reward 199.217129.
# Average reward for episode 200.000000.  Total average reward 199.224957.
# Average reward for episode 193.400000.  Total average reward 199.166708.
# Average reward for episode 200.000000.  Total average reward 199.175041.
# Average reward for episode 200.000000.  Total average reward 199.183290.
# Average reward for episode 200.000000.  Total average reward 199.191458.
# Average reward for episode 200.000000.  Total average reward 199.199543.
# Average reward for episode 198.000000.  Total average reward 199.187548.
# Average reward for episode 200.000000.  Total average reward 199.195672.
# Average reward for episode 193.400000.  Total average reward 199.137715.
# Average reward for episode 200.000000.  Total average reward 199.146338.
# Average reward for episode 197.600000.  Total average reward 199.130875.
# Average reward for episode 200.000000.  Total average reward 199.139566.
# Average reward for episode 200.000000.  Total average reward 199.148170.
# Average reward for episode 200.000000.  Total average reward 199.156689.
# Average reward for episode 196.400000.  Total average reward 199.129122.
# Average reward for episode 192.600000.  Total average reward 199.063831.
# Average reward for episode 200.000000.  Total average reward 199.073192.
# Average reward for episode 200.000000.  Total average reward 199.082460.
# Average reward for episode 200.000000.  Total average reward 199.091636.
# Average reward for episode 191.600000.  Total average reward 199.016719.
# Average reward for episode 195.000000.  Total average reward 198.976552.
# Average reward for episode 200.000000.  Total average reward 198.986787.
# Average reward for episode 200.000000.  Total average reward 198.996919.
# Average reward for episode 200.000000.  Total average reward 199.006950.
# Average reward for episode 199.200000.  Total average reward 199.008880.
# Average reward for episode 200.000000.  Total average reward 199.018791.
# Average reward for episode 195.600000.  Total average reward 198.984603.
# Average reward for episode 200.000000.  Total average reward 198.994757.
# Average reward for episode 200.000000.  Total average reward 199.004810.
# Average reward for episode 197.200000.  Total average reward 198.986762.
# Average reward for episode 197.400000.  Total average reward 198.970894.
# Average reward for episode 190.000000.  Total average reward 198.881185.
# Average reward for episode 200.000000.  Total average reward 198.892373.
# Average reward for episode 200.000000.  Total average reward 198.903450.
# Average reward for episode 200.000000.  Total average reward 198.914415.
# Average reward for episode 200.000000.  Total average reward 198.925271.
# Average reward for episode 191.800000.  Total average reward 198.854018.
# Average reward for episode 200.000000.  Total average reward 198.865478.
# Average reward for episode 200.000000.  Total average reward 198.876823.
# Average reward for episode 200.000000.  Total average reward 198.888055.
# Average reward for episode 188.000000.  Total average reward 198.779174.
# Average reward for episode 199.600000.  Total average reward 198.787383.
# Average reward for episode 200.000000.  Total average reward 198.799509.
# Average reward for episode 200.000000.  Total average reward 198.811514.
# Average reward for episode 194.000000.  Total average reward 198.763399.
# Average reward for episode 200.000000.  Total average reward 198.775765.
# Average reward for episode 191.400000.  Total average reward 198.702007.
# Average reward for episode 183.600000.  Total average reward 198.550987.
# Average reward for episode 190.200000.  Total average reward 198.467477.
# Average reward for episode 190.000000.  Total average reward 198.382802.
# Average reward for episode 194.400000.  Total average reward 198.342974.
# Average reward for episode 200.000000.  Total average reward 198.359545.
# Average reward for episode 198.400000.  Total average reward 198.359949.
# Average reward for episode 189.600000.  Total average reward 198.272350.
# Average reward for episode 200.000000.  Total average reward 198.289626.
# Average reward for episode 191.400000.  Total average reward 198.220730.
# Average reward for episode 200.000000.  Total average reward 198.238523.
# Average reward for episode 200.000000.  Total average reward 198.256137.
# Average reward for episode 200.000000.  Total average reward 198.273576.
# Average reward for episode 200.000000.  Total average reward 198.290840.
# Average reward for episode 200.000000.  Total average reward 198.307932.
# Average reward for episode 199.800000.  Total average reward 198.322852.
# Average reward for episode 193.000000.  Total average reward 198.269624.
# Average reward for episode 200.000000.  Total average reward 198.286928.
# Average reward for episode 200.000000.  Total average reward 198.304058.
# Average reward for episode 195.000000.  Total average reward 198.271018.
# Average reward for episode 200.000000.  Total average reward 198.288308.
# Average reward for episode 200.000000.  Total average reward 198.305425.
# Average reward for episode 193.000000.  Total average reward 198.252370.
# Average reward for episode 200.000000.  Total average reward 198.269847.
# Average reward for episode 200.000000.  Total average reward 198.287148.
# Average reward for episode 200.000000.  Total average reward 198.304277.
# Average reward for episode 200.000000.  Total average reward 198.321234.
# Average reward for episode 200.000000.  Total average reward 198.338022.
# Average reward for episode 195.200000.  Total average reward 198.306641.
# Average reward for episode 200.000000.  Total average reward 198.323575.
# Average reward for episode 200.000000.  Total average reward 198.340339.
# Average reward for episode 196.000000.  Total average reward 198.316936.
# Average reward for episode 200.000000.  Total average reward 198.333766.
# Average reward for episode 200.000000.  Total average reward 198.350429.
# Average reward for episode 200.000000.  Total average reward 198.366925.
# Average reward for episode 195.200000.  Total average reward 198.335255.
# Average reward for episode 200.000000.  Total average reward 198.351903.
# Average reward for episode 200.000000.  Total average reward 198.368384.
# Average reward for episode 200.000000.  Total average reward 198.384700.
# Average reward for episode 200.000000.  Total average reward 198.400853.
# Average reward for episode 200.000000.  Total average reward 198.416844.
# Average reward for episode 200.000000.  Total average reward 198.432676.
# Average reward for episode 200.000000.  Total average reward 198.448349.
# Average reward for episode 200.000000.  Total average reward 198.463866.
# Average reward for episode 197.600000.  Total average reward 198.455227.
# Average reward for episode 200.000000.  Total average reward 198.470675.
# Average reward for episode 200.000000.  Total average reward 198.485968.
# Average reward for episode 200.000000.  Total average reward 198.501108.
# Average reward for episode 200.000000.  Total average reward 198.516097.
# Average reward for episode 200.000000.  Total average reward 198.530936.
# Average reward for episode 200.000000.  Total average reward 198.545627.
# Average reward for episode 200.000000.  Total average reward 198.560171.
# Average reward for episode 200.000000.  Total average reward 198.574569.
# Average reward for episode 200.000000.  Total average reward 198.588823.
# Average reward for episode 200.000000.  Total average reward 198.602935.
# Average reward for episode 200.000000.  Total average reward 198.616906.
# Average reward for episode 194.200000.  Total average reward 198.572737.
# Average reward for episode 199.400000.  Total average reward 198.581009.
# Average reward for episode 200.000000.  Total average reward 198.595199.
# Average reward for episode 191.400000.  Total average reward 198.523247.
# Average reward for episode 200.000000.  Total average reward 198.538015.
# Average reward for episode 200.000000.  Total average reward 198.552634.
# Average reward for episode 200.000000.  Total average reward 198.567108.
# Average reward for episode 200.000000.  Total average reward 198.581437.
# Average reward for episode 200.000000.  Total average reward 198.595623.
# Average reward for episode 200.000000.  Total average reward 198.609666.
# Average reward for episode 200.000000.  Total average reward 198.623570.
# Average reward for episode 200.000000.  Total average reward 198.637334.
# Average reward for episode 200.000000.  Total average reward 198.650961.
# Average reward for episode 200.000000.  Total average reward 198.664451.
# Average reward for episode 200.000000.  Total average reward 198.677807.
# Average reward for episode 193.000000.  Total average reward 198.621029.
# Average reward for episode 200.000000.  Total average reward 198.634818.
# Average reward for episode 200.000000.  Total average reward 198.648470.
# Average reward for episode 200.000000.  Total average reward 198.661985.
# Average reward for episode 200.000000.  Total average reward 198.675366.
# Average reward for episode 200.000000.  Total average reward 198.688612.
# Average reward for episode 200.000000.  Total average reward 198.701726.
# Average reward for episode 200.000000.  Total average reward 198.714709.
# Average reward for episode 200.000000.  Total average reward 198.727561.
# Average reward for episode 188.600000.  Total average reward 198.626286.
# Average reward for episode 200.000000.  Total average reward 198.640023.
# Average reward for episode 200.000000.  Total average reward 198.653623.
# Average reward for episode 200.000000.  Total average reward 198.667087.
# Average reward for episode 197.000000.  Total average reward 198.650416.
# Average reward for episode 200.000000.  Total average reward 198.663911.
# Average reward for episode 200.000000.  Total average reward 198.677272.
# Average reward for episode 200.000000.  Total average reward 198.690500.
# Average reward for episode 197.000000.  Total average reward 198.673595.
# Average reward for episode 200.000000.  Total average reward 198.686859.
# Average reward for episode 195.200000.  Total average reward 198.651990.
# Average reward for episode 200.000000.  Total average reward 198.665470.
# Average reward for episode 200.000000.  Total average reward 198.678816.
# Average reward for episode 200.000000.  Total average reward 198.692027.
# Average reward for episode 200.000000.  Total average reward 198.705107.
# Average reward for episode 198.400000.  Total average reward 198.702056.
# Average reward for episode 190.800000.  Total average reward 198.623035.
# Average reward for episode 200.000000.  Total average reward 198.636805.
# Average reward for episode 197.200000.  Total average reward 198.622437.
# Average reward for episode 200.000000.  Total average reward 198.636213.
# Average reward for episode 193.800000.  Total average reward 198.587851.
# Average reward for episode 189.000000.  Total average reward 198.491972.
# Average reward for episode 193.200000.  Total average reward 198.439052.
# Average reward for episode 200.000000.  Total average reward 198.454662.
# Average reward for episode 182.600000.  Total average reward 198.296115.
# Average reward for episode 182.200000.  Total average reward 198.135154.
# Average reward for episode 200.000000.  Total average reward 198.153802.
# Average reward for episode 189.200000.  Total average reward 198.064264.
# Average reward for episode 196.000000.  Total average reward 198.043622.
# Average reward for episode 197.200000.  Total average reward 198.035186.
# Average reward for episode 185.600000.  Total average reward 197.910834.
# Average reward for episode 193.000000.  Total average reward 197.861725.
# Average reward for episode 193.800000.  Total average reward 197.821108.
# Average reward for episode 197.000000.  Total average reward 197.812897.
# Average reward for episode 191.400000.  Total average reward 197.748768.
# Average reward for episode 172.800000.  Total average reward 197.499280.
# Average reward for episode 173.800000.  Total average reward 197.262288.
# Average reward for episode 183.200000.  Total average reward 197.121665.
# Average reward for episode 183.000000.  Total average reward 196.980448.
# Average reward for episode 178.600000.  Total average reward 196.796644.
# Average reward for episode 184.200000.  Total average reward 196.670677.
# Average reward for episode 151.200000.  Total average reward 196.215970.
# Average reward for episode 150.200000.  Total average reward 195.755811.
# Average reward for episode 168.600000.  Total average reward 195.484253.
# Average reward for episode 157.200000.  Total average reward 195.101410.
# Average reward for episode 189.800000.  Total average reward 195.048396.
# Average reward for episode 157.400000.  Total average reward 194.671912.
# Average reward for episode 200.000000.  Total average reward 194.725193.
# Average reward for episode 172.600000.  Total average reward 194.503941.
# Average reward for episode 149.800000.  Total average reward 194.056902.
# Average reward for episode 184.400000.  Total average reward 193.960333.
# Average reward for episode 165.000000.  Total average reward 193.670729.
# Average reward for episode 165.200000.  Total average reward 193.386022.
# Average reward for episode 178.400000.  Total average reward 193.236162.
# Average reward for episode 154.000000.  Total average reward 192.843800.
# Average reward for episode 167.000000.  Total average reward 192.585362.
# Average reward for episode 199.800000.  Total average reward 192.657508.
# Average reward for episode 183.200000.  Total average reward 192.562933.
# Average reward for episode 151.400000.  Total average reward 192.151304.
# Average reward for episode 200.000000.  Total average reward 192.229791.
# [2017-05-25 16:28:59,360] Starting new video recorder writing to /tmp/cartpole-experiment-3/openaigym.video.0.6558.video010000.mp4
# Average reward for episode 188.200000.  Total average reward 192.189493.
# 10001 Episodes completed.

# %%
# env.close()
gym.upload('/tmp/cartpole-experiment-3', api_key='sk_WZ0h9zAS6e9BWgfvUeCsQ')
# Out:
# [2017-05-25 16:31:21,314] [CartPole-v0] Uploading 10000 episodes of training data
# [2017-05-25 16:31:23,289] [CartPole-v0] Uploading videos of 20 training episodes (181901 bytes)
# [2017-05-25 16:31:23,910] [CartPole-v0] Creating evaluation object from /tmp/cartpole-experiment-3 with learning curve and training video
# [2017-05-25 16:31:24,220]
# ****************************************************
# You successfully uploaded your evaluation on CartPole-v0 to
# OpenAI Gym! You can find it at:
#
#     https://gym.openai.com/evaluations/eval_xyQALBq8SMyXO6yOMRcwOg
#
# ****************************************************
